# %%
# Visualize DC Property Data
# Due No Due Date  Points 10  Submitting a website url

# Create 3 different visualizations of the DC property data, submit the notebook to github
# and submit the url for the repository here.

LARRY LARKIN

# %%
# Load libraries
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Load datafile
filename = "datasets/datasets/DC_Properties.csv"
df = pd.read_csv(filename)
df.head(5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# ...

# %%
# List all column headings
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
# Find what type of number is PRICE
df['PRICE'].dtypes
# Out:
# dtype('float64')

# %%
df['PRICE'].head(10)
# Out:
# 0    1095000.0
# 1          NaN
# 2    2100000.0
# 3    1602000.0
# 4          NaN
# 5    1950000.0
# 6          NaN
# 7    1050000.0
# 8    1430000.0
# 9          NaN
# Name: PRICE, dtype: float64

# %%
# Find max value of PRICE
df['PRICE'].max()
# Out:
# 137427545.0

# %%
# Bin data by price range
#Define bins as 0-249K, 250-499K, 500-749K, 750-999K, 1000-149000K
bins = [0, 250000, 500000, 750000, 1000000, 149000000]

# Create names for the four groups
group_names = ['0-249K', '250-499K', '500-749K', '750-999K', '1,000-149,000K']

#make new column with letter grades
df['Price Range'] = pd.cut(df['PRICE'], bins, labels=group_names)
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL       ...        ASSESSMENT_NBHD  ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0       ...             Old City 2    040 D Old City 2
# 1  1898.0   2007.0       ...             Old City 2    040 D Old City 2
# 2  1910.0   2009.0       ...             Old City 2    040 D Old City 2
# 3  1900.0   2003.0       ...             Old City 2    040 D Old City 2
# 4  1913.0   2012.0       ...             Old City 2    040 D Old City 2
#
# ...

# %%
df_histogram=pd.value_counts(df['Price Range']) # number of observations per letter grade
df_histogram
# Out:
# 250-499K          34521
# 0-249K            26527
# 500-749K          18916
# 750-999K           9359
# 1,000-149,000K     8893
# Name: Price Range, dtype: int64

# %%
plt.hist(df_histogram)
# Out:
# (array([2., 0., 0., 1., 0., 0., 1., 0., 0., 1.]),
#  array([ 8893. , 11455.8, 14018.6, 16581.4, 19144.2, 21707. , 24269.8,
#         26832.6, 29395.4, 31958.2, 34521. ]),
#  <a list of 10 Patch objects>)

# %%
########### GRAPH # 2 ###############################################################################################

# PRICE AS A FUNCTION OF NO. OF BEDROOMS

# Datafile
df.head(5)
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL       ...        ASSESSMENT_NBHD  ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0       ...             Old City 2    040 D Old City 2
# 1  1898.0   2007.0       ...             Old City 2    040 D Old City 2
# 2  1910.0   2009.0       ...             Old City 2    040 D Old City 2
# 3  1900.0   2003.0       ...             Old City 2    040 D Old City 2
# 4  1913.0   2012.0       ...             Old City 2    040 D Old City 2
#
# ...

# %%
sns.lmplot(x='BEDRM', y='PRICE', data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['PRICE'].size
# Out:
# 158957

# %%
# Remove outliers
# Use standard deviation method
meanprice = df['PRICE'].mean()
stdprice = df['PRICE'].std()
toprange = meanprice + stdprice * 1.96
botrange = meanprice - stdprice * 1.96

df_outlier = df #Create working copy of main datafile
df_outlier = df_outlier.drop(df_outlier[df_outlier['PRICE'] > toprange].index)
df_outlier = df_outlier.drop(df_outlier[df_outlier['PRICE'] < botrange].index)

df_outlier.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL       ...        ASSESSMENT_NBHD  ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0       ...             Old City 2    040 D Old City 2
# 1  1898.0   2007.0       ...             Old City 2    040 D Old City 2
# 2  1910.0   2009.0       ...             Old City 2    040 D Old City 2
# 3  1900.0   2003.0       ...             Old City 2    040 D Old City 2
# 4  1913.0   2012.0       ...             Old City 2    040 D Old City 2
#
# ...

# %%
df_outlier['PRICE'].size
# Out:
# 158589

# %%
# Plot data without outliers
sns.lmplot(x='BEDRM', y='PRICE', data=df_outlier)

# %%
########### GRAPH # 3 ###############################################################################################

# LOT SIZE vs. PRICE

# Datafile
df.head(5)
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL       ...        ASSESSMENT_NBHD  ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0       ...             Old City 2    040 D Old City 2
# 1  1898.0   2007.0       ...             Old City 2    040 D Old City 2
# 2  1910.0   2009.0       ...             Old City 2    040 D Old City 2
# 3  1900.0   2003.0       ...             Old City 2    040 D Old City 2
# 4  1913.0   2012.0       ...             Old City 2    040 D Old City 2
#
# ...

# %%
#swarm plot
plt.subplots(figsize=(10,6))
sns.swarmplot(x='LANDAREA', y='PRICE', data=df)

# %%
# Remove outliers
# Use standard deviation method
meanprice1 = df['PRICE'].mean()
stdprice1 = df['PRICE'].std()
toprange1 = meanprice1 + stdprice1 * 1.96
botrange1 = meanprice1 - stdprice1 * 1.96

df_outlier1 = df #Create working copy of main datafile
df_outlier1 = df_outlier1.drop(df_outlier1[df_outlier1['PRICE'] > toprange].index)
df_outlier1 = df_outlier1.drop(df_outlier1[df_outlier1['PRICE'] < botrange].index)

df_outlier1.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL       ...        ASSESSMENT_NBHD  ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0       ...             Old City 2    040 D Old City 2
# 1  1898.0   2007.0       ...             Old City 2    040 D Old City 2
# 2  1910.0   2009.0       ...             Old City 2    040 D Old City 2
# 3  1900.0   2003.0       ...             Old City 2    040 D Old City 2
# 4  1913.0   2012.0       ...             Old City 2    040 D Old City 2
#
# ...

# %%
# Swarm plot without outliers
plt.subplots(figsize=(15,6))
sns.swarmplot(x='LANDAREA', y='PRICE', data=df_outlier1)
